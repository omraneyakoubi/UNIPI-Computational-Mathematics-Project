# %%
from torchvision import datasets

# %%
dataset = datasets.MNIST(root = "./data", train = True, download = False)

# %%
X = dataset.data
y = dataset.targets

# %%
X_vctr = X.reshape(-1, 784)

# %%
X = X_vctr.float()/255

# %%
print(f"Shape of X: {X.shape}") # Should be torch.Size([60000, 784])
# Out:
# Shape of X: torch.Size([60000, 784])
